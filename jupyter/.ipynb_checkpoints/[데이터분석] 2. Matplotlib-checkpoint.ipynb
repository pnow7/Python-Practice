# %% [markdown]
# ## 차트를 멋지게 그려보자

# %% [markdown]
# ※ 출처 :  생능출판사 "따라하며 배우는 파이썬과 데이터과학"

# %% [markdown]
# ### 11.2 matplotlib 무작정 사용해 보기

# %% [markdown]
# * **데이터 시각화data visualization** 는 점이나 선, 막대 그래프등의 시각적 이미지를 사용하여 데이터를 화면에 표시하는 기술
# * 효과적인 시각화는 사용자가 데이터를 분석하고 추론하는 데 도움이 된다. **사람들은 시각적으로 보이는 데이터를 직관적으로 이해** 할 수 있기 때문이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * matplotlib은 가장 널리 사용되는 시각화 도구이다.
# * 간단한 막대 그래프, 선 그래프, 산포도를 그리는 용도로는 matplotlib가 제격이다.

# %% [markdown]
# #### 맷플롯립 코드 살펴 보기

# %% [markdown]
# ### 11.3 차트 장식을 도와주는 다양한 기법들

# %% [markdown]
# * plot() 함수를 수정하여 한 번의 호출만으로  $2𝑥, 𝑥^2+5, −𝑥^2−5$의 세 함수를 그려보도록 하자.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### LAB 11-1 수학 함수도 쉽게 그려보자

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11.4 하나의 차트에 여러 개의 데이터를 그려보자

# %% [markdown]
# * 리스트 x를 다음과 같이 선언하고 이를 리스트 x, y, z와 함께 그려보자.
# * 여기에 각 차트를 설명하는 **범례(legend)** 를 추가하면 다음과 같다.

# %% [markdown]
# ### LAB 11-2 삼각함수의 기본인 사인 그래프 그리기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11.5 막대형 차트도 손쉽게 그려보자

# %% [markdown]
# * plt.bar() 함수를 호출하여 화면에 막대형 차트를 그릴 수 있다.
# * 앞의 1인당 국민소득을 막대 그래프로 그려보자.

# %% [markdown]
# #### 여러 나라의 국민소득 추이를 다중 막대형 차트로 그리자

# %% [markdown]
# * 한국(kr)뿐만 아니라 일본(jp), 중국(ch)의 국민소득 추이를 다중 막대형 차트로 그려보자.
# * 어떤 방법을 사용할까? 아래와 같이 데이터 리스트를 먼저 만들자.

# %% [markdown]
# * 두께를 0.25로 줄여보자. 그리고 가로축의 범위는 세 개의 막대형 차트가 공유해야 하는 것이므로 아래와 같이 변수에 담아 공유해서 사용하자

# %% [markdown]
# * 이전 페이지의 표는 알아보기가 힘든 단점이 있다.
# * 각 막대의 가로축 범위를 조금씩 차이를 두는 방법을  사용
# * 그런데 정수 범위를 생성하는 range() 함수의 결과에 실수값을 더하는 것은 불가능
# * 실수 범위를 생성하는 넘파이의 범위로 변경하여 다음과 같이 완성

# %% [markdown]
# ### 11.6 데이터를 점으로 표현하는 산포도 그래프 그리기

# %% [markdown]
# * **산포도 플롯scatter plot** 은 개별 데이터 포인트를 그리는 차트. 산포도를 그릴 때는 각 데이터 포인트가 연결되지 않는다. 산포도 그래프를 그릴 때는 scatter() 함수를 사용함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 원형 비율을 표시하는 파이 차트 만들기

# %% [markdown]
# * **파이 차트pie chart** 는 데이터의 값에 따라서 원형 비율로 나누어져 있는 차트
# * 파이 차트는 비즈니스 세계에서 널리 사용(예들 들어, 상품의 시장 점유율을 표시)

# %% [markdown]
# ### 11.7 히스토그램으로 자료의 분포를 한눈에 살펴보자

# %% [markdown]
# * **히스토그램histogram** 은 주어진 자료를 몇 개의 구간으로 나누고 각 구간의 도수frequency를 조사하여 나타낸 막대 그래프이다

# %% [markdown]
# #### 겹쳐진 히스토그램도 그리자 : 다중 히스토그램

# %% [markdown]
# ### LAB 11-3 정규분포로 생성된 난수를 눈으로 확인하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### LAB 11-4 차종별 판매량을 파이 차트로 표현하자

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11.8 데이터를 효율적으로 표현하는 상자 차트를 알아보자

# %% [markdown]
# **상자 차트box plot** 는 데이터의 최대, 최소, 중간값과 사분위 수 등을 효율적으로 가시화 할 수 있는 방법이다. 데이터의 범위를 표시하는 선을 수염이라고 불러 **상자-수염box-and-whisker 차트** 라고도 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 여러 개의 상자 차트 그리기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11.9 한 화면에 여러 그래프 그리기 : subplots()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### LAB 11-5 서브플롯 이용해 보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **핵심 정리**
# ![image.png](attachment:image.png)
